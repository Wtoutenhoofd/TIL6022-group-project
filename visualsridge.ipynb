# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img1 = mpimg.imread("ridgepredictedvsactualvalues.png")  
img2 = mpimg.imread("ridgeaveragerror.png") 
img3 = mpimg.imread("ridgemostimportantfeatures.png")
img4 = mpimg.imread("ridgevisualtrainingpredictionsplit.png") 
img5 = mpimg.imread("ridgesensorsaffectedvessels.png") 


plt.imshow(img1)                 
plt.show()

# %% [markdown]
# Deze Grafiek laat zien hoe goed de voorspellingen zijn. ALs alle voorspellingen perfect waren geweest lagen ze op de rode lijn, het model doet het redelijk goed bij lage aantallen maar is niet in staat hoge aantallen te voorspellen waardoor als de echte waardes hoog oplopen het model systematisch 'underpredicts'

# %% [markdown]
# #

# %%
plt.imshow(img2)                 
plt.show()

# %% [markdown]
# Deze grafiek laat zien hoever het model er gemiddeld vanaf zit. het laat een beetje een vertekend beeld zien. Omdat de meeste waardes laag zijn en goed worden gegokt hebben veel voorspellingen een lage error maar de voorspellingen die er het meest toe doen (als ergens opeens te veel mensen zijn) wordt systematisch te laag gegokt zoals in de vorige grafiek is te zien. Goed om deze er wel bij te zetten maar duidelijk te maken dat de resultaten minder goed zijn dan hier is te zien.

# %%
plt.imshow(img3)
plt.show()

# %% [markdown]
# Deze grafiek laat zien welke 3 factoren waarop getest is de grootste invloed uitoefenen. Je kan concluderen dat als het gaat regenen het goed is om extra op te letten (mensen naar bepaalde drukke plekken te sturen waar menigtes worden verwacht) Temperatuur is verrassend ook groter dan de vessels. Het effect is waarschijnlijk zelfs groter gemaakt dan dat het is omdat dag en nacht ook mee worden genomen (in de nacht is het rustiger maar niet per se doordat het kouder is) Verder kun je vermelden dat temperatuur een grotere rol kan spelen dan hier wordt vermeld (door heat stress of kou).

# %%
plt.imshow(img4)
plt.show()

# %% [markdown]
# Deze grafiek laat zien welk deel van de data is gebruikt voor training en welk deel voor testen
# opmerkingen:
# Kan niet voor alles rekening mee gehouden worden, zit bijvoorbeeld maar 1 weekenddag in de train data terwijl test data allemaal in het weekend is (alleen zondag) wat voor slechtere resultaten kan zorgen.
# Zondag is ook de uittocht waardoor op een gegeven moment alle schepen weg zijn, daarom is het ook niet de beste dag om op te testen.

# %%
plt.imshow(img5)
plt.show()

# %% [markdown]
# Deze grafiek laat zien welke sensoren het meest beïnvloed worden door de aanwezigheid van schepen. De locaties van de sensoren zijn terug te vinden in sensor-location.xlsx.
# Misschien leuk om in het verslag een kaart op te nemen waarop de sensoren te zien zijn die het sterkst worden beïnvloed. Daarbij kun je vermelden dat op deze locaties extra aandacht of controle nodig is ofzo
# Verder kun je hieruit concluderen dat de sensoren bij het water meer last hebben van drukte door schepen (vrij logisch maar goed om expliciet te melden)
